# %%
import os

#is the notebook running on Colab?
if 'COLAB_JUPYTER_TRANSPORT' in os.environ.keys():
    isColab = True
    sourcedir =os.getcwd()+ "/CPlantBox"
    filedir = sourcedir +"/tutorial/jupyter/fspm_2023"
else:
    isColab = False
    sourcedir = os.getcwd()+"/../../.."
    filedir = os.getcwd()
#this can take some minutes
if isColab:
    # downloading the source code
    ! git clone https://github.com/Plant-Root-Soil-Interactions-Modelling/CPlantBox --depth=1 --single-branch -b stable_v2.1
    os.chdir(sourcedir)
    # !apt install libeigen3-dev
    ! apt install llvm-dev
    # !pip3 install vtk
    # !sudo DEBIAN_FRONTEND=noninteractive apt-get install -yq xvfb
    # !pip install -q 'xvfbwrapper~=0.2.9'
    if 'vdisplay' not in globals():
        # start a virtual X display for MAGICAL rendering
        import xvfbwrapper
        vdisplay = xvfbwrapper.Xvfb()
        vdisplay.start()
    os.environ["CUDA_VISIBLE_DEVICES"] = "1"


    if os.path.exists("./src/external/pybind11"):
        ! rm -rf src/external/pybind11 #delete folder
    ! git rm -r --cached src/external/pybind11 #take out git cache for pybind11
    ! git submodule add --force -b stable https://github.com/pybind/pybind11.git ./src/external/pybind11


    ! git pull
    ! cmake .
    ! make
    os.chdir(filedir)

# %% [markdown]
# # Workshop 6.2024 - (3/4)
#
# ## Simulation of xylem water movement
#
#
# In the following we will show how to compute:
#
# 1. xylem water flux for a root segment for a pre-defined maximum transpiration
#
# 2. xylem water flux and photosynthesis rate for a whole plant
#
# We consider static root system and a static soil.
# To compute the water xylem flux we use the hybrid analytical approach of Meunier et al. (2017). Note that the model ist static (as most models are). To compute the photosynthesis rate and stomatal egulation, we use the FcVB-Leuning methode, as presented by Tuzet et al. (2003).
#
# **Reference**
#
# F Meunier, X Draye, J Vanderborght, M Javaux, V Couvreur. A hybrid analytical-numerical method for solving water flow equations in root hydraulic architectures. *Applied Mathematical modelling*, 2017.
#
# A Tuzet, A Perrier, R Leuning. A coupled model of stomatal conductance, photosynthesis and transpiration. *Plant, Cell & Environment*, 2003.

# %%
import sys; sys.path.append(sourcedir); sys.path.append(sourcedir+"/src")
import plantbox as pb
from functional.xylem_flux import XylemFluxPython  # Python hybrid solver
import visualisation.vtk_plot as vp # for quick 3d vizualisations
import numpy as np
import matplotlib.pyplot as plt
from functional.photosynthesis_cpp import PhotosynthesisPython

# %% [markdown]
# ## 1. xylem flux in the root system
#
# We present a minimal example with constant conductivities (based on *example6b_xylemflux.py*), where we give the soil water total potential per segment

# %%
""" root system """
simtime = 14  # [day] 
rs = pb.MappedRootSystem() # handles conductivity and mapping to the soil cells
path = "../../../modelparameter/structural/rootsystem/"
name = "Anagallis_femina_Leitner_2010"  # Zea_mays_1_Leitner_2010
rs.readParameters(path + name + ".xml")
random_parameters = rs.getRootRandomParameter()
verbose = False
for p in random_parameters[1:]:
    p.dx = 0.25 
rs.initialize(verbose) # note that an artificial root with type =0 is added in MappedRootSystem
rs.simulate(simtime,verbose)
_ = vp.plot_roots(pb.SegmentAnalyser(rs.mappedSegments()), "subType",interactiveImage = not isColab) 

""" Parameters """
kz = 4.32e-2  # axial conductivity [cm^3/day]
kr = 1.728e-4  # radial conductivity [1/day]
p_top = -300  # top soil pressure [cm]
p0 = -500  # dirichlet bc at root collar [cm]
trans = -1.2  # neuman bc at root collar [cm3/day]

""" prepare soil matric potentials per segment"""
segs = rs.segments # MappedRootSystem has access to segments and nodes 
nodes = rs.nodes
p_s = np.zeros((len(segs),)) # soil total potentials around each root segment
for i, s in enumerate(segs):
    p_s[i] = p_top - 0.5 * (nodes[s.x].z + nodes[s.y].z)  # constant total potential (hydraulic equilibrium)

""" root problem """
r = XylemFluxPython(rs)
r.setKr([0., kr, kr , kr, kr, kr]) # no radial flux into the artificial root segment
r.setKx([1., kz, kz, kz, kz, kz])

""" Numerical solution """
#
# In the following 'cells = False' means total soil potentials 'p_s' is given for each segment
#

# rx = r.solve_neumann(simtime, trans, p_s, cells = False) # use Neumann bc 
# rx = r.solve_dirichlet(simtime, p0, 0, p_s, cells = False) # use Dirichlet bc
rx = r.solve(simtime, trans, 0, p_s, cells= False, wilting_point = -15000) # use Neumann, switch to Dirichlet if below wilting_point

fluxes1 = r.segFluxes(simtime, rx, p_s, cells = False)  # [cm3/day]
print("Transpiration", r.collar_flux(simtime, rx, [p_s], k_soil = [], cells = False), "cm3/day")
# Out:
# Transpiration -1.2000000000000077 cm3/day

# %%
surfs = np.multiply(np.array(r.rs.segLength()), 2*np.array(r.rs.radii)*np.pi)  # root segment side surface [cm2]
fluxes = np.divide(fluxes1, surfs)  # we convert to [cm3/(cm2 day)]

""" plot results """
ana = pb.SegmentAnalyser(r.rs.mappedSegments())
ana.addData("rx", rx) # add simulation result
_ = vp.plot_roots(ana, "rx", "Xylem matric potential (cm)",interactiveImage = not isColab)  
ana.addData("fluxes", fluxes) # add simulation result 
_ = vp.plot_roots(ana, "fluxes", "Segment flux (cm/day)",interactiveImage = not isColab) 


fig, ax = plt.subplots()
name = ["root", "stem", "leaf"]
color = ['tab:blue', 'tab:orange', 'tab:green']
for ndType in [2, 3, 4]:
    #nodes = self.get_nodes()
    y = r.get_nodes_organ_type(ndType)#coordinates
    x = np.array(rx)[r.get_nodes_index(ndType)]
    ax.scatter(x, y[:,2], c=color[ndType-2],  label=name[ndType-2],
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)
plt.xlabel("Xylem pressure (cm)")
plt.ylabel("Depth (cm)")
plt.title("Xylem matric potential (cm)")
plt.show()


fig, ax = plt.subplots()
name = ["root", "stem", "leaf"]
color = ['tab:blue', 'tab:orange', 'tab:green']
for ndType in [2, 3, 4]:
    segIdx = r.get_segments_index(ndType)
    nodesy = segIdx + np.ones(segIdx.shape, dtype = np.int64)
    nodes = r.get_nodes()
    y = np.array(nodes)[nodesy]#coordinates
    x = fluxes[segIdx]
    ax.scatter(x, y[:,2], c=color[ndType-2],  label=name[ndType-2],
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)
plt.xlabel("Fluxes (cm/day)")
plt.ylabel("Depth (cm)")
plt.title("water fluxes")
plt.show()

# %% [markdown]
# ## Take away messages
#
# * Basic idea how to use the class *XylemFluxPython*
# * How to set the root axial and radial conductivities in the class *MappedRootSystem*
# * Look at the outputs of the xylem model

# %% [markdown]
# ## 2. Xylem flux in the whole plant and photosynthesis
#
# We present a minimal example with constant conductivities.

# %%
simtime = 14  # [day] 
pl = pb.MappedPlant() #for plant objects
path = "../../../modelparameter/structural/plant/" 
name = "fspm2023" 
pl.readParameters(path + name + ".xml")

soilSpace = pb.SDF_PlantContainer(500,500, 500, True) #to avoid root growing aboveground
pl.setGeometry(soilSpace) # creates soil space to stop roots from growing out of the soil

verbose = False
pl.initialize(verbose)
pl.simulate(simtime,verbose)

# %% [markdown]
# We set the parameters:

# %%
kz = 4.32e-2  # axial conductivity [cm3/day]
kr_root = 1.728e-4  # radial conductivity [1/day]
kr_stem = 0  # radial conductivity of stem  [1/day], set to 0
kr_leaf =  0.004 #  radial conductivity of leaf xylem membrane [1/day] different from stomatal conductance
depth = 60 #cm
p_top = -1000  # top soil total potential [cm]
p_bot = p_top +depth # bot total potential [cm]

#envirenmental variables
RH = 0.5 # relative humidity [-]
TairC = 20 #air temperature [°C]
TairK = TairC + 273.15
Q = 900e-6 #irradiance [mol quanta m-2 s-1]
cs = 350e-6 #co2 partial pressure at leaf surface [mol mol-1]
es = 0.61078 * np.exp(17.27 * TairC / (TairC + 237.3))/10 # [hPa] #from FAO56
ea = es * RH


Rgaz=8.314 #J K-1 mol-1 = cm^3*MPa/K/mol
rho_h2o = 1 #g/cm3
Mh2o = 18.05 #g/mol
MPa2hPa = 10000
hPa2cm = 1.0197                     
p_a = np.log(RH)*Rgaz*rho_h2o*TairK/Mh2o *MPa2hPa*hPa2cm #air water potential [cm]


#we give as input the initial guess of water potential and internal CO2 concentration
#for the fixed-point iteration
r = PhotosynthesisPython(pl, min(p_s), cs*0.7) #Equivalent to XylemFluxPython() for whole plant

# %% [markdown]
# We give the total potential per soil voxel:

# %%
" Coupling to soil "
z_ = np.linspace(0,-depth,depth) # 0, -1, -2, ... -35

p_s = np.linspace(p_top, p_bot, depth)
soil_index = lambda x,y,z : max(int(np.floor(-z)),-1) #abovegroud nodes get index -1
pl.setSoilGrid(soil_index)

# %% [markdown]
# Create object to compute water flow:

# %%
""" Set up organ conductivities and atmospheric conditions"""

r.setKr([[kr_root],[kr_stem],[kr_leaf]]) 
r.setKx([[kz]])
r.airPressure = p_a 
r.Qlight = Q;

# %% [markdown]
# Launche simulation:

# %%
#
# In the following 'cells = True' means total soil potentials 'p_s' is given for soil voxel
#
r.solve_photosynthesis(ea_=ea, es_ = es, sim_time_ = simtime, sxx_=p_s, cells_ = True, TairC_ = TairC)
# Make sure to let the solve_photosynthesis() function finish before starting the block of code below.
# Out:
# OrganRandomParameter::readSuccessor: for parameter of organ 2, subType 1, 'ruleId' (and 'number') not found in successor definition. Use defeault ruleId instead: 0
# OrganRandomParameter::readSuccessor: for parameter of organ 2, subType 2, 'ruleId' (and 'number') not found in successor definition. Use defeault ruleId instead: 0
# OrganRandomParameter::readSuccessor: for parameter of organ 2, subType 3, 'ruleId' (and 'number') not found in successor definition. Use defeault ruleId instead: 0
# leuning computation module at 0 trials. Sum of max relative error calculated at the last two trials: 0
# each val 1.23446 inf inf 0.185026 1 inf 0 inf inf
# each val abs 368.485 9.82729e-06 0.174857 0.000245 298.544 0.308502 0 7.24493 0.000265337
# leuning computation module at 1 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0807383 0.000411819 0.00511248 0.00097324 0.105363 0.324693 0 10.7989 0.0111191
# each val abs 26.865 4.0454e-09 0.000889408 2.82288e-07 35.1601 0.0756164 0 0.571022 1.09226e-07
# leuning computation module at 2 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0622649 5.14992e-05 0.000635821 0.000121612 0.0737049 0.205759 0 8.61797 0.000520329
# each val abs 22.1931 5.05863e-10 0.000110542 3.52692e-08 26.5526 0.0397412 0 0.367154 5.11118e-09
# leuning computation module at 3 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0557322 3.93299e-05 0.000485215 9.28647e-05 0.0583922 0.137284 0 7.71169 0.000507036
# each val abs 20.0516 3.86312e-10 8.43172e-05 2.69295e-08 22.0289 0.023315 0 0.291279 4.98049e-09
# leuning computation module at 4 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0498168 3.29183e-05 0.000405882 7.7719e-05 0.0526453 0.100151 0 7.098 0.00049501
# each val abs 18.9223 3.23324e-10 7.05027e-05 2.25357e-08 20.0183 0.0154602 0 0.238418 4.86226e-09
# leuning computation module at 5 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0445722 2.99025e-05 0.0003687 7.0599e-05 0.0473054 0.0799962 0 6.68032 0.000483869
# each val abs 17.7734 2.93704e-10 6.40465e-05 2.04713e-08 18.881 0.0114343 0 0.203681 4.75273e-09
# leuning computation module at 6 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0405657 2.84035e-05 0.000350062 6.70554e-05 0.0425365 0.0685465 0 6.39516 0.000473393
# each val abs 16.6911 2.78973e-10 6.07878e-05 1.94425e-08 17.7317 0.00952346 0 0.18146 4.64975e-09
# leuning computation module at 7 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0381552 2.68525e-05 0.000330808 6.33897e-05 0.0389395 0.0630946 0 6.17764 0.000463455
# each val abs 15.7025 2.63732e-10 5.74253e-05 1.83785e-08 16.6519 0.00865473 0 0.164828 4.55205e-09
# leuning computation module at 8 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.035776 2.53751e-05 0.000312484 5.98984e-05 0.0367022 0.0603328 0 5.99696 0.000453976
# each val abs 14.8989 2.49216e-10 5.42274e-05 1.73652e-08 15.6667 0.00780968 0 0.150934 4.45888e-09
# leuning computation module at 9 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0334934 2.40143e-05 0.000295615 5.66829e-05 0.0344876 0.0574298 0 5.84447 0.000444905
# each val abs 14.4473 2.35845e-10 5.12849e-05 1.64321e-08 14.884 0.00703017 0 0.139202 4.36971e-09
# leuning computation module at 10 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0313405 2.27771e-05 0.000280286 5.37598e-05 0.0323557 0.0546122 0 5.7157 0.0004362
# each val abs 13.9715 2.2369e-10 4.86119e-05 1.55838e-08 14.4309 0.00633906 0 0.129376 4.28415e-09
# leuning computation module at 11 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0293318 2.20994e-05 0.000272056 5.21635e-05 0.0303377 0.0519862 0 5.62336 0.00042783
# each val abs 13.4858 2.1704e-10 4.72006e-05 1.51221e-08 13.9542 0.00573606 0 0.12301 4.20188e-09
# leuning computation module at 12 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0274703 2.14798e-05 0.000264341 5.06983e-05 0.0284481 0.049583 0 5.54264 0.000419769
# each val abs 13.0004 2.1095e-10 4.585e-05 1.46966e-08 13.4681 0.00521245 0 0.117476 4.12265e-09
# leuning computation module at 13 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0257529 2.08351e-05 0.000256326 4.91742e-05 0.026691 0.0473991 0 5.46964 0.000411995
# each val abs 12.5225 2.04614e-10 4.44483e-05 1.42541e-08 12.9828 0.00475737 0 0.112422 4.04623e-09
# leuning computation module at 14 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0241727 2.01809e-05 0.000248201 4.7628e-05 0.0250645 0.0454169 0 5.40321 0.000404486
# each val abs 12.0568 1.98186e-10 4.30288e-05 1.38052e-08 12.5051 0.00436038 0 0.107779 3.97243e-09
# leuning computation module at 15 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0227209 1.95284e-05 0.000240106 4.60861e-05 0.0235634 0.0436142 0 5.3424 0.000397225
# each val abs 11.6066 1.91775e-10 4.16153e-05 1.33577e-08 12.0399 0.00401232 0 0.103494 3.90107e-09
# leuning computation module at 16 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0213881 1.88858e-05 0.000232138 4.45676e-05 0.0221803 0.0419688 0 5.28644 0.000390196
# each val abs 11.174 1.85461e-10 4.0225e-05 1.2917e-08 11.5903 0.00379489 0 0.0995215 3.83199e-09
# leuning computation module at 17 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0201645 1.82587e-05 0.000224366 4.30857e-05 0.0209072 0.0404603 0 5.23472 0.000383386
# each val abs 10.7601 1.79299e-10 3.88696e-05 1.2487e-08 11.1583 0.00363019 0 0.0958256 3.76506e-09
# leuning computation module at 18 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0191658 1.76508e-05 0.000216839 4.16497e-05 0.0197356 0.0390706 0 5.18737 0.00037678
# each val abs 10.3654 1.73327e-10 3.75574e-05 1.20703e-08 10.7451 0.00346122 0 0.0924361 3.70014e-09
# leuning computation module at 19 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0185776 1.70648e-05 0.000209585 4.02653e-05 0.0187701 0.0377845 0 5.14714 0.000370368
# each val abs 9.98992 1.67569e-10 3.62934e-05 1.16686e-08 10.3511 0.00329203 0 0.0896193 3.63713e-09
# leuning computation module at 20 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0180858 1.65021e-05 0.000202623 3.8936e-05 0.0182044 0.0371472 0 5.1095 0.000364138
# each val abs 9.63345 1.62041e-10 3.50807e-05 1.12829e-08 9.97631 0.0031255 0 0.0869655 3.5759e-09
# leuning computation module at 21 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0177538 1.59634e-05 0.000195961 3.76636e-05 0.0177488 0.0365096 0 5.0776 0.000358079
# each val abs 9.29542 1.56749e-10 3.39206e-05 1.09138e-08 9.62053 0.00296365 0 0.0847701 3.51636e-09
# leuning computation module at 22 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0174145 1.54489e-05 0.000189601 3.64484e-05 0.0174276 0.0358291 0 5.04877 0.000352184
# each val abs 8.97515 1.51695e-10 3.28134e-05 1.05613e-08 9.28317 0.00280781 0 0.0827929 3.45843e-09
# leuning computation module at 23 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0170703 1.49584e-05 0.000183538 3.52898e-05 0.0170993 0.0351197 0 5.02152 0.000346443
# each val abs 8.67187 1.46876e-10 3.17584e-05 1.02252e-08 8.96354 0.00265884 0 0.0808996 3.40201e-09
# leuning computation module at 24 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0167233 1.44912e-05 0.000177767 3.41865e-05 0.0167661 0.0343927 0 4.99575 0.000340848
# each val abs 8.38474 1.42287e-10 3.07544e-05 9.90521e-09 8.66088 0.00251723 0 0.079084 3.34703e-09
# leuning computation module at 25 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0163753 1.40467e-05 0.000172278 3.31368e-05 0.0164302 0.0336572 0 4.97138 0.000335392
# each val abs 8.1129 1.3792e-10 2.97995e-05 9.60074e-09 8.37434 0.00238318 0 0.0773404 3.29341e-09
# leuning computation module at 26 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0160278 1.3624e-05 0.000167059 3.21386e-05 0.0160932 0.0329207 0 4.94831 0.000330067
# each val abs 7.85549 1.33768e-10 2.88919e-05 9.31122e-09 8.10305 0.00225674 0 0.075664 3.24109e-09
# leuning computation module at 27 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0156819 1.32221e-05 0.000162098 3.11895e-05 0.0157565 0.032189 0 4.9265 0.000324868
# each val abs 7.64424 1.2982e-10 2.80295e-05 9.03598e-09 7.84616 0.00213777 0 0.0740502 3.19001e-09
# leuning computation module at 28 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0153387 1.284e-05 0.000157383 3.02872e-05 0.0154213 0.031467 0 4.90586 0.000319789
# each val abs 7.53311 1.26067e-10 2.72098e-05 8.77432e-09 7.63665 0.00202607 0 0.0724952 3.14009e-09
# leuning computation module at 29 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.014999 1.24766e-05 0.0001529 2.94293e-05 0.0150885 0.0307585 0 4.88634 0.000314823
# each val abs 7.42262 1.22498e-10 2.64308e-05 8.52553e-09 7.52555 0.00192135 0 0.070995 3.0913e-09
# leuning computation module at 30 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0146636 1.2131e-05 0.000148638 2.86133e-05 0.014759 0.0300663 0 4.86788 0.000309966
# each val abs 7.35978 1.19103e-10 2.56902e-05 8.2889e-09 7.41511 0.00182329 0 0.0695465 3.04358e-09
# leuning computation module at 31 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0143331 1.18022e-05 0.000144853 2.78369e-05 0.0144334 0.0293929 0 4.85044 0.000305213
# each val abs 7.29935 1.15873e-10 2.50825e-05 8.06551e-09 7.35587 0.00173156 0 0.0681465 2.99687e-09
# leuning computation module at 32 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0140078 1.16525e-05 0.000143068 2.74933e-05 0.0141124 0.0287398 0 4.83396 0.000300559
# each val abs 7.23594 1.1442e-10 2.47698e-05 7.96705e-09 7.29522 0.00164579 0 0.0667922 2.95114e-09
# leuning computation module at 33 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0136881 1.15092e-05 0.000141284 2.71545e-05 0.0137964 0.0281084 0 4.81839 0.000295999
# each val abs 7.16987 1.13012e-10 2.44576e-05 7.86868e-09 7.23161 0.00156562 0 0.0654809 2.90634e-09
# leuning computation module at 34 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0133744 1.1408e-05 0.000140165 2.69193e-05 0.0134856 0.0274995 0 4.8037 0.000291531
# each val abs 7.10145 1.12025e-10 2.42817e-05 7.80162e-09 7.16536 0.00149071 0 0.0642103 2.86244e-09
# leuning computation module at 35 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0130669 1.1333e-05 0.000139221 2.67418e-05 0.0131805 0.0269136 0 4.78983 0.00028715
# each val abs 7.03095 1.11288e-10 2.41148e-05 7.74996e-09 7.09678 0.00142071 0 0.0629782 2.8194e-09
# leuning computation module at 36 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0127657 1.12536e-05 0.000138223 2.65537e-05 0.0128812 0.026351 0 4.77675 0.000282852
# each val abs 6.95863 1.10507e-10 2.39385e-05 7.69526e-09 7.02614 0.0013553 0 0.0617825 2.77717e-09
# leuning computation module at 37 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0124709 1.11702e-05 0.000137175 2.63562e-05 0.0125879 0.0258118 0 4.76443 0.000278635
# each val abs 6.88472 1.09686e-10 2.37538e-05 7.63781e-09 6.9537 0.00129417 0 0.0606214 2.73574e-09
# leuning computation module at 38 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0121826 1.10831e-05 0.000136083 2.615e-05 0.0123008 0.0252959 0 4.75281 0.000274496
# each val abs 6.80945 1.0883e-10 2.35615e-05 7.57786e-09 6.87968 0.00123701 0 0.0594929 2.69507e-09
# leuning computation module at 39 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0119009 1.09927e-05 0.000134951 2.5936e-05 0.0120198 0.0248029 0 4.74188 0.000270431
# each val abs 6.733 1.07941e-10 2.33623e-05 7.51565e-09 6.80432 0.00119671 0 0.0583956 2.65514e-09
# leuning computation module at 40 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0116257 1.08992e-05 0.000133782 2.5715e-05 0.011745 0.0243325 0 4.73159 0.000266438
# each val abs 6.65557 1.07022e-10 2.31569e-05 7.45141e-09 6.72779 0.0011812 0 0.0573279 2.61591e-09
# leuning computation module at 41 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0113569 1.08031e-05 0.000132581 2.54876e-05 0.0114765 0.0238843 0 4.72192 0.000262514
# each val abs 6.57733 1.06077e-10 2.2946e-05 7.38534e-09 6.6503 0.00116554 0 0.0562884 2.57736e-09
# leuning computation module at 42 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0110947 1.07046e-05 0.000131351 2.52546e-05 0.0112142 0.0234575 0 4.71282 0.000258658
# each val abs 6.49842 1.05109e-10 2.27302e-05 7.31764e-09 6.572 0.0011498 0 0.0552757 2.53948e-09
# leuning computation module at 43 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0108389 1.0604e-05 0.000130096 2.50166e-05 0.0109581 0.0230517 0 4.70428 0.000254866
# each val abs 6.41901 1.0412e-10 2.251e-05 7.24848e-09 6.49305 0.001134 0 0.0542886 2.50223e-09
# leuning computation module at 44 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0105893 1.05015e-05 0.000128818 2.47741e-05 0.0107081 0.0226662 0 4.69626 0.000251138
# each val abs 6.33921 1.03112e-10 2.2286e-05 7.17805e-09 6.4136 0.00111818 0 0.0533261 2.4656e-09
# leuning computation module at 45 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.010346 1.03973e-05 0.00012752 2.45277e-05 0.0104641 0.0223003 0 4.68874 0.00024747
# each val abs 6.25915 1.02088e-10 2.20586e-05 7.10648e-09 6.33378 0.00110237 0 0.0523869 2.42957e-09
# leuning computation module at 46 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0101089 1.02916e-05 0.000126205 2.42779e-05 0.0102262 0.0219533 0 4.6817 0.000243861
# each val abs 6.17894 1.0105e-10 2.18284e-05 7.03394e-09 6.2537 0.0010866 0 0.0514702 2.39412e-09
# leuning computation module at 47 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00987773 1.01847e-05 0.000124875 2.40252e-05 0.00999412 0.0216244 0 4.67509 0.00024031
# each val abs 6.09869 9.9999e-11 2.15957e-05 6.96055e-09 6.17348 0.00107089 0 0.0505749 2.35923e-09
# leuning computation module at 48 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00965248 1.00768e-05 0.000123533 2.37699e-05 0.00976784 0.021313 0 4.66892 0.000236815
# each val abs 6.01848 9.8938e-11 2.13609e-05 6.88644e-09 6.09322 0.00105526 0 0.0497002 2.3249e-09
# leuning computation module at 49 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.009433 9.96792e-06 0.00012218 2.35126e-05 0.00954724 0.0210183 0 4.66314 0.000233374
# each val abs 5.9384 9.78682e-11 2.11244e-05 6.81173e-09 6.01302 0.00103973 0 0.0488454 2.2911e-09
# leuning computation module at 50 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00921917 9.85833e-06 0.000120819 2.32536e-05 0.0093322 0.0207396 0 4.65774 0.000229986
# each val abs 5.85854 9.67912e-11 2.08866e-05 6.73652e-09 5.93295 0.00102431 0 0.0480095 2.25782e-09
# leuning computation module at 51 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00901086 9.74814e-06 0.000119451 2.29931e-05 0.00912261 0.0204762 0 4.65271 0.000226649
# each val abs 5.77895 9.57085e-11 2.06477e-05 6.66093e-09 5.8531 0.00100902 0 0.0471919 2.22504e-09
# leuning computation module at 52 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00880795 9.63752e-06 0.000118079 2.27317e-05 0.00891835 0.0202273 0 4.64801 0.000223363
# each val abs 5.69972 9.46214e-11 2.0408e-05 6.58504e-09 5.77354 0.000993865 0 0.0463919 2.19276e-09
# leuning computation module at 53 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00861029 9.52656e-06 0.000116703 2.24695e-05 0.0087193 0.0199924 0 4.64364 0.000220126
# each val abs 5.62089 9.35312e-11 2.01678e-05 6.50894e-09 5.69433 0.000978855 0 0.0456089 2.16097e-09
# leuning computation module at 54 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00841776 9.41541e-06 0.000115325 2.22069e-05 0.00852533 0.0197707 0 4.63957 0.000216937
# each val abs 5.54252 9.2439e-11 1.99274e-05 6.43271e-09 5.61552 0.000964 0 0.0448422 2.12965e-09
# leuning computation module at 55 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00823022 9.30417e-06 0.000113946 2.1944e-05 0.00833632 0.0195616 0 4.63579 0.000213795
# each val abs 5.46465 9.1346e-11 1.9687e-05 6.35644e-09 5.53719 0.000949306 0 0.0440914 2.09878e-09
# leuning computation module at 56 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00804756 9.19294e-06 0.000112569 2.16812e-05 0.00815215 0.0193645 0 4.63229 0.000210699
# each val abs 5.38734 9.02531e-11 1.94468e-05 6.28017e-09 5.45936 0.00093478 0 0.0433558 2.06837e-09
# leuning computation module at 57 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00786962 9.08181e-06 0.000111193 2.14187e-05 0.00797269 0.0191788 0 4.62904 0.000207648
# each val abs 5.31063 8.91613e-11 1.9207e-05 6.20399e-09 5.38209 0.000921874 0 0.0426349 2.0384e-09
# leuning computation module at 58 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0076963 8.97087e-06 0.00010982 2.11566e-05 0.00779782 0.0190038 0 4.62604 0.000204641
# each val abs 5.23453 8.80714e-11 1.89677e-05 6.12795e-09 5.30541 0.000914308 0 0.0419284 2.00887e-09
# leuning computation module at 59 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00752746 8.86021e-06 0.000108451 2.08952e-05 0.00762742 0.0188391 0 4.62327 0.000201677
# each val abs 5.1591 8.69842e-11 1.87292e-05 6.05211e-09 5.22936 0.000906362 0 0.0412357 1.97976e-09
# leuning computation module at 60 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00736297 8.74989e-06 0.000107087 2.06346e-05 0.00746137 0.0186841 0 4.62072 0.000198755
# each val abs 5.08436 8.59004e-11 1.84916e-05 5.97651e-09 5.15397 0.00089808 0 0.0405564 1.95106e-09
# leuning computation module at 61 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00720273 8.63999e-06 0.000105728 2.0375e-05 0.00729955 0.0185383 0 4.61838 0.000195875
# each val abs 5.01032 8.48208e-11 1.82551e-05 5.90121e-09 5.07927 0.000889499 0 0.0398902 1.92278e-09
# leuning computation module at 62 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0070466 8.53057e-06 0.000104376 2.01166e-05 0.00714185 0.0184011 0 4.61623 0.000193036
# each val abs 4.93702 8.37459e-11 1.80197e-05 5.82624e-09 5.00529 0.000880654 0 0.0392365 1.89489e-09
# leuning computation module at 63 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00689447 8.42169e-06 0.00010303 1.98594e-05 0.00698816 0.0182722 0 4.61427 0.000190237
# each val abs 4.86448 8.26762e-11 1.77857e-05 5.75165e-09 4.93204 0.000871577 0 0.0385952 1.8674e-09
# leuning computation module at 64 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00674623 8.3134e-06 0.000101693 1.96037e-05 0.00683836 0.018151 0 4.61249 0.000187477
# each val abs 4.7927 8.16125e-11 1.7553e-05 5.67748e-09 4.85954 0.000862299 0 0.0379658 1.8403e-09
# leuning computation module at 65 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00660177 8.20575e-06 0.000100364 1.93495e-05 0.00669234 0.0180372 0 4.61088 0.000184756
# each val abs 4.72171 8.0555e-11 1.73219e-05 5.60374e-09 4.78782 0.000852848 0 0.0373479 1.81358e-09
# leuning computation module at 66 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00646098 8.09878e-06 9.90437e-05 1.90969e-05 0.00655 0.0179304 0 4.60942 0.000182073
# each val abs 4.65152 7.95043e-11 1.70923e-05 5.53049e-09 4.71689 0.000843249 0 0.0367414 1.78723e-09
# leuning computation module at 67 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00632374 7.99254e-06 9.77327e-05 1.8846e-05 0.00641123 0.0178301 0 4.60811 0.000179427
# each val abs 4.58214 7.84607e-11 1.68644e-05 5.45773e-09 4.64675 0.000833525 0 0.0361458 1.76125e-09
# leuning computation module at 68 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00618997 7.88707e-06 9.64316e-05 1.8597e-05 0.00627594 0.017736 0 4.60694 0.000176819
# each val abs 4.51357 7.74247e-11 1.66383e-05 5.38551e-09 4.57742 0.000823698 0 0.035561 1.73563e-09
# leuning computation module at 69 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00605956 7.78239e-06 9.51407e-05 1.83498e-05 0.00614403 0.0176478 0 4.60591 0.000174246
# each val abs 4.44582 7.63964e-11 1.6414e-05 5.31384e-09 4.50891 0.000813789 0 0.0349866 1.71037e-09
# leuning computation module at 70 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00593241 7.67853e-06 9.38603e-05 1.81046e-05 0.00601539 0.017565 0 4.60501 0.00017171
# each val abs 4.37891 7.53764e-11 1.61916e-05 5.24274e-09 4.44122 0.000803814 0 0.0344223 1.68546e-09
# leuning computation module at 71 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00580842 7.57553e-06 9.25908e-05 1.78615e-05 0.00588994 0.0174875 0 4.60423 0.000169208
# each val abs 4.31283 7.43647e-11 1.59711e-05 5.17223e-09 4.37436 0.000793793 0 0.033868 1.66089e-09
# leuning computation module at 72 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00568752 7.47342e-06 9.13325e-05 1.76204e-05 0.00576758 0.0174149 0 4.60356 0.000166741
# each val abs 4.24758 7.33618e-11 1.57526e-05 5.10233e-09 4.30834 0.000783738 0 0.0333234 1.63667e-09
# leuning computation module at 73 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0055696 7.3722e-06 9.00857e-05 1.73815e-05 0.00564823 0.0173469 0 4.603 0.000164309
# each val abs 4.18318 7.23677e-11 1.55362e-05 5.03306e-09 4.24315 0.000773666 0 0.0327883 1.61278e-09
# leuning computation module at 74 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00545458 7.27191e-06 8.88505e-05 1.71447e-05 0.0055318 0.0172833 0 4.60255 0.00016191
# each val abs 4.11961 7.13827e-11 1.53218e-05 4.96442e-09 4.1788 0.000763589 0 0.0322624 1.58923e-09
# leuning computation module at 75 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00534238 7.17256e-06 8.76272e-05 1.69102e-05 0.0054182 0.0172237 0 4.6022 0.000159544
# each val abs 4.05687 7.04069e-11 1.51095e-05 4.89643e-09 4.11528 0.000753518 0 0.0317456 1.566e-09
# leuning computation module at 76 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00523292 7.07417e-06 8.6416e-05 1.6678e-05 0.00530737 0.0171681 0 4.60194 0.000157211
# each val abs 3.99498 6.94406e-11 1.48994e-05 4.8291e-09 4.05261 0.000743465 0 0.0312376 1.54309e-09
# leuning computation module at 77 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00512611 6.97674e-06 8.52171e-05 1.6448e-05 0.00519921 0.0171161 0 4.60177 0.00015491
# each val abs 3.93392 6.84838e-11 1.46914e-05 4.76244e-09 3.99077 0.000733439 0 0.0307382 1.5205e-09
# leuning computation module at 78 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00502188 6.8803e-06 8.40305e-05 1.62204e-05 0.00509365 0.0170676 0 4.60168 0.000152641
# each val abs 3.87369 6.75366e-11 1.44856e-05 4.69645e-09 3.92977 0.00072345 0 0.0302474 1.49822e-09
# leuning computation module at 79 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00492016 6.78485e-06 8.28563e-05 1.59951e-05 0.00499063 0.0170223 0 4.60168 0.000150404
# each val abs 3.81429 6.65993e-11 1.42821e-05 4.63115e-09 3.86959 0.000713505 0 0.0297648 1.47625e-09
# leuning computation module at 80 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00482088 6.6904e-06 8.16948e-05 1.57722e-05 0.00489006 0.0169801 0 4.60176 0.000148197
# each val abs 3.75571 6.56717e-11 1.40807e-05 4.56654e-09 3.81025 0.000703612 0 0.0292903 1.45458e-09
# leuning computation module at 81 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00472396 6.59696e-06 8.05459e-05 1.55517e-05 0.00479188 0.0169408 0 4.60191 0.000146021
# each val abs 3.69794 6.47541e-11 1.38815e-05 4.50263e-09 3.75172 0.000693778 0 0.0288238 1.43322e-09
# leuning computation module at 82 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00462935 6.50454e-06 7.94097e-05 1.53336e-05 0.00469602 0.0169042 0 4.60214 0.000143876
# each val abs 3.641 6.38465e-11 1.36846e-05 4.43941e-09 3.69402 0.000684009 0 0.028365 1.41215e-09
# leuning computation module at 83 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00453696 6.41313e-06 7.82863e-05 1.51179e-05 0.00460241 0.0168701 0 4.60243 0.00014176
# each val abs 3.58485 6.29489e-11 1.349e-05 4.37689e-09 3.63712 0.00067431 0 0.0279139 1.39137e-09
# leuning computation module at 84 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00444675 6.32275e-06 7.71757e-05 1.49046e-05 0.004511 0.0168385 0 4.60279 0.000139673
# each val abs 3.52951 6.20613e-11 1.32976e-05 4.31508e-09 3.58104 0.000664687 0 0.0274702 1.37088e-09
# leuning computation module at 85 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00435865 6.23339e-06 7.6078e-05 1.46937e-05 0.00442172 0.0168091 0 4.60321 0.000137615
# each val abs 3.47497 6.11838e-11 1.31074e-05 4.25397e-09 3.52575 0.000655143 0 0.0270339 1.35068e-09
# leuning computation module at 86 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00427259 6.14506e-06 7.4993e-05 1.44853e-05 0.00433451 0.0167819 0 4.60369 0.000135586
# each val abs 3.42121 6.03164e-11 1.29196e-05 4.19357e-09 3.47126 0.000645683 0 0.0266048 1.33076e-09
# leuning computation module at 87 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00418853 6.05776e-06 7.39209e-05 1.42793e-05 0.00424931 0.0167567 0 4.60424 0.000133585
# each val abs 3.36823 5.94591e-11 1.27339e-05 4.13388e-09 3.41756 0.00063631 0 0.0261827 1.31111e-09
# leuning computation module at 88 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00410641 5.97148e-06 7.28616e-05 1.40757e-05 0.00416608 0.0167335 0 4.60484 0.000131612
# each val abs 3.31602 5.86119e-11 1.25505e-05 4.07488e-09 3.36463 0.000627027 0 0.0257675 1.29174e-09
# leuning computation module at 89 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00402618 5.88622e-06 7.18151e-05 1.38746e-05 0.00408475 0.016712 0 4.60549 0.000129667
# each val abs 3.26458 5.77748e-11 1.23694e-05 4.0166e-09 3.31248 0.000617837 0 0.0253591 1.27264e-09
# leuning computation module at 90 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00394778 5.80199e-06 7.07813e-05 1.36759e-05 0.00400527 0.0166922 0 4.6062 0.000127748
# each val abs 3.2139 5.69477e-11 1.21904e-05 3.95902e-09 3.26109 0.000608743 0 0.0249574 1.25381e-09
# leuning computation module at 91 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00387116 5.71879e-06 6.97602e-05 1.34796e-05 0.0039276 0.016674 0 4.60695 0.000125857
# each val abs 3.16396 5.61307e-11 1.20138e-05 3.90213e-09 3.21045 0.000599746 0 0.0245622 1.23524e-09
# leuning computation module at 92 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00379627 5.63659e-06 6.87518e-05 1.32857e-05 0.00385167 0.0166574 0 4.60776 0.000123992
# each val abs 3.11477 5.53237e-11 1.18393e-05 3.84595e-09 3.16057 0.000590848 0 0.0241735 1.21693e-09
# leuning computation module at 93 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00372307 5.55542e-06 6.77561e-05 1.30942e-05 0.00377746 0.0166421 0 4.60862 0.000122153
# each val abs 3.06631 5.45266e-11 1.1667e-05 3.79046e-09 3.11143 0.000582051 0 0.023791 1.19887e-09
# leuning computation module at 94 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00365151 5.47525e-06 6.67729e-05 1.2905e-05 0.00370491 0.0166282 0 4.60952 0.00012034
# each val abs 3.01857 5.37395e-11 1.14969e-05 3.73567e-09 3.06301 0.000573356 0 0.0234147 1.18107e-09
# leuning computation module at 95 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00358155 5.39608e-06 6.58021e-05 1.27183e-05 0.00363397 0.0166156 0 4.61047 0.000118552
# each val abs 2.97154 5.29622e-11 1.13291e-05 3.68156e-09 3.01532 0.000564765 0 0.0230445 1.16352e-09
# leuning computation module at 96 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00351314 5.31792e-06 6.48438e-05 1.25339e-05 0.00356461 0.0166042 0 4.61147 0.000116789
# each val abs 2.92523 5.21947e-11 1.11633e-05 3.62814e-09 2.96835 0.000556277 0 0.0226803 1.14622e-09
# leuning computation module at 97 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00344625 5.24074e-06 6.38978e-05 1.23519e-05 0.00349677 0.016594 0 4.61251 0.000115051
# each val abs 2.87961 5.1437e-11 1.09998e-05 3.5754e-09 2.92208 0.000547894 0 0.0223219 1.12916e-09
# leuning computation module at 98 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00338083 5.16456e-06 6.29641e-05 1.21722e-05 0.00343043 0.0165848 0 4.61359 0.000113338
# each val abs 2.83468 5.0689e-11 1.08384e-05 3.52334e-09 2.87651 0.000539615 0 0.0219693 1.11234e-09
# leuning computation module at 99 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00331684 5.08935e-06 6.20425e-05 1.19948e-05 0.00336554 0.0165766 0 4.61471 0.000111649
# each val abs 2.79043 4.99506e-11 1.06791e-05 3.47195e-09 2.83162 0.000531442 0 0.0216224 1.09575e-09
# leuning computation module at 100 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00325424 5.01512e-06 6.1133e-05 1.18197e-05 0.00330206 0.0165694 0 4.61588 0.000109984
# each val abs 2.74685 4.92218e-11 1.05219e-05 3.42123e-09 2.78742 0.000523375 0 0.021281 1.07941e-09
# leuning computation module at 101 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00319301 4.94186e-06 6.02355e-05 1.16469e-05 0.00323996 0.0165631 0 4.61709 0.000108342
# each val abs 2.70394 4.85025e-11 1.03668e-05 3.37118e-09 2.74389 0.000515413 0 0.0209451 1.06329e-09
# leuning computation module at 102 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0031331 4.86955e-06 5.93499e-05 1.14763e-05 0.0031792 0.0165577 0 4.61833 0.000106724
# each val abs 2.66168 4.77926e-11 1.02137e-05 3.32178e-09 2.70102 0.000507557 0 0.0206146 1.0474e-09
# leuning computation module at 103 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00307448 4.7982e-06 5.8476e-05 1.1308e-05 0.00311975 0.0165531 0 4.61962 0.000105128
# each val abs 2.62006 4.70921e-11 1.00628e-05 3.27303e-09 2.6588 0.000499806 0 0.0202894 1.03174e-09
# leuning computation module at 104 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00301712 4.72779e-06 5.76139e-05 1.1142e-05 0.00306157 0.0165493 0 4.62094 0.000103556
# each val abs 2.57908 4.64008e-11 9.91384e-06 3.22493e-09 2.61723 0.000492159 0 0.0199693 1.0163e-09
# leuning computation module at 105 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00296098 4.65831e-06 5.67633e-05 1.09781e-05 0.00300463 0.0165462 0 4.62231 0.000102005
# each val abs 2.53873 4.57187e-11 9.76692e-06 3.17747e-09 2.5763 0.000484618 0 0.0196544 1.00108e-09
# leuning computation module at 106 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00290604 4.58976e-06 5.59242e-05 1.08165e-05 0.00294889 0.0165439 0 4.62371 0.000100477
# each val abs 2.499 4.50457e-11 9.622e-06 3.13064e-09 2.53599 0.00047718 0 0.0193445 9.86081e-10
# leuning computation module at 107 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00285225 4.52213e-06 5.50964e-05 1.0657e-05 0.00289434 0.0165422 0 4.62515 9.89706e-05
# each val abs 2.45988 4.43818e-11 9.47906e-06 3.08445e-09 2.4963 0.000469845 0 0.0190395 9.71293e-10
# leuning computation module at 108 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00279961 4.45542e-06 5.428e-05 1.04996e-05 0.00284093 0.0165411 0 4.62663 9.74856e-05
# each val abs 2.42136 4.37268e-11 9.33809e-06 3.03888e-09 2.45722 0.000462614 0 0.0187393 9.56716e-10
# leuning computation module at 109 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00274806 4.3896e-06 5.34746e-05 1.03444e-05 0.00278865 0.0165477 0 4.62814 9.60219e-05
# each val abs 2.38343 4.30807e-11 9.19905e-06 2.99393e-09 2.41874 0.000455485 0 0.018444 9.42348e-10
# leuning computation module at 110 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0026976 4.32468e-06 5.26803e-05 1.01913e-05 0.00273746 0.0165566 0 4.6297 9.45792e-05
# each val abs 2.34609 4.24433e-11 9.06193e-06 2.94959e-09 2.38085 0.000448457 0 0.0181533 9.28186e-10
# leuning computation module at 111 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00264818 4.26064e-06 5.18969e-05 1.00403e-05 0.00268733 0.0165657 0 4.63129 9.31572e-05
# each val abs 2.30933 4.18146e-11 8.92671e-06 2.90585e-09 2.34355 0.000441529 0 0.0178673 9.14227e-10
# leuning computation module at 112 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00259979 4.19747e-06 5.11244e-05 9.89138e-06 0.00263824 0.0165749 0 4.63292 9.17555e-05
# each val abs 2.27313 4.11946e-11 8.79337e-06 2.86271e-09 2.30683 0.000434702 0 0.0175858 9.00469e-10
# leuning computation module at 113 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0025524 4.13517e-06 5.03625e-05 9.74449e-06 0.00259016 0.0165844 0 4.63459 9.03741e-05
# each val abs 2.2375 4.0583e-11 8.6619e-06 2.82017e-09 2.27067 0.000427973 0 0.0173087 8.86909e-10
# leuning computation module at 114 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00250598 4.07373e-06 4.96112e-05 9.59961e-06 0.00254307 0.016594 0 4.63629 8.90125e-05
# each val abs 2.20241 3.99799e-11 8.53226e-06 2.77822e-09 2.23507 0.000421342 0 0.0170361 8.73544e-10
# leuning computation module at 115 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00246051 4.01314e-06 4.88704e-05 9.45674e-06 0.00249694 0.0166038 0 4.63803 8.76706e-05
# each val abs 2.16787 3.9385e-11 8.40443e-06 2.73684e-09 2.20003 0.000414808 0 0.0167678 8.60372e-10
# leuning computation module at 116 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00241598 3.95339e-06 4.81399e-05 9.31585e-06 0.00245176 0.0166138 0 4.63981 8.63481e-05
# each val abs 2.13387 3.87985e-11 8.27841e-06 2.69604e-09 2.16553 0.00040837 0 0.0165037 8.4739e-10
# leuning computation module at 117 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00237235 3.89446e-06 4.74196e-05 9.17692e-06 0.00240749 0.0166241 0 4.64163 8.50446e-05
# each val abs 2.1004 3.822e-11 8.15416e-06 2.65581e-09 2.13156 0.000402026 0 0.0162438 8.34596e-10
# leuning computation module at 118 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0023296 3.83636e-06 4.67095e-05 9.03992e-06 0.00236412 0.0166345 0 4.64348 8.37601e-05
# each val abs 2.06744 3.76497e-11 8.03167e-06 2.61614e-09 2.09812 0.000395777 0 0.015988 8.21987e-10
# leuning computation module at 119 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00228771 3.77907e-06 4.60093e-05 8.90484e-06 0.00232163 0.0166451 0 4.64538 8.24941e-05
# each val abs 2.035 3.70873e-11 7.91092e-06 2.57703e-09 2.0652 0.000389621 0 0.0157363 8.09561e-10
# leuning computation module at 120 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00224667 3.72258e-06 4.53191e-05 8.77166e-06 0.00227999 0.0166559 0 4.64731 8.12465e-05
# each val abs 2.00306 3.65328e-11 7.79188e-06 2.53846e-09 2.03279 0.000383556 0 0.0154886 7.97315e-10
# leuning computation module at 121 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00220645 3.66688e-06 4.46386e-05 8.64034e-06 0.00223918 0.0166669 0 4.64928 8.00171e-05
# each val abs 1.97162 3.5986e-11 7.67454e-06 2.50044e-09 2.00089 0.000377583 0 0.0152447 7.85248e-10
# leuning computation module at 122 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00216703 3.61197e-06 4.39677e-05 8.51088e-06 0.00219919 0.0166782 0 4.65129 7.88055e-05
# each val abs 1.94067 3.5447e-11 7.55887e-06 2.46295e-09 1.96949 0.000371698 0 0.0150047 7.73356e-10
# leuning computation module at 123 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0021284 3.55783e-06 4.33064e-05 8.38325e-06 0.00215999 0.0166896 0 4.65334 7.76116e-05
# each val abs 1.91021 3.49156e-11 7.44486e-06 2.426e-09 1.93857 0.000365903 0 0.0147686 7.61637e-10
# leuning computation module at 124 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00209053 3.50446e-06 4.26546e-05 8.25742e-06 0.00212157 0.0167013 0 4.65543 7.64351e-05
# each val abs 1.88021 3.43917e-11 7.33248e-06 2.38956e-09 1.90814 0.000360195 0 0.0145361 7.50089e-10
# leuning computation module at 125 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00205341 3.45184e-06 4.2012e-05 8.13338e-06 0.00208391 0.0167131 0 4.65756 7.52757e-05
# each val abs 1.85069 3.38752e-11 7.22172e-06 2.35365e-09 1.87818 0.000354573 0 0.0143073 7.3871e-10
# leuning computation module at 126 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00201702 3.39997e-06 4.13786e-05 8.0111e-06 0.00204698 0.0167252 0 4.65973 7.41333e-05
# each val abs 1.82163 3.33661e-11 7.11255e-06 2.31824e-09 1.84868 0.000349036 0 0.0140821 7.27497e-10
# leuning computation module at 127 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00198135 3.34884e-06 4.07543e-05 7.89056e-06 0.00201079 0.0167375 0 4.66194 7.30077e-05
# each val abs 1.79302 3.28642e-11 7.00495e-06 2.28335e-09 1.81965 0.000343584 0 0.0138605 7.16448e-10
# leuning computation module at 128 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00194637 3.29844e-06 4.0139e-05 7.77175e-06 0.0019753 0.0167501 0 4.66419 7.18985e-05
# each val abs 1.76486 3.23694e-11 6.89891e-06 2.24895e-09 1.79107 0.000338215 0 0.0136424 7.05561e-10
# leuning computation module at 129 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00191208 3.24876e-06 3.95325e-05 7.65463e-06 0.0019405 0.0167629 0 4.66649 7.08055e-05
# each val abs 1.73714 3.18818e-11 6.7944e-06 2.21504e-09 1.76294 0.000332927 0 0.0134277 6.94834e-10
# leuning computation module at 130 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00187845 3.19979e-06 3.89347e-05 7.5392e-06 0.00190638 0.0167759 0 4.66882 6.97286e-05
# each val abs 1.70985 3.14011e-11 6.69141e-06 2.18162e-09 1.73525 0.000327721 0 0.0132164 6.84265e-10
# leuning computation module at 131 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00184548 3.15152e-06 3.83456e-05 7.42542e-06 0.00187292 0.0167891 0 4.67121 6.86676e-05
# each val abs 1.68299 3.09274e-11 6.58991e-06 2.14868e-09 1.70799 0.000322594 0 0.0130085 6.7385e-10
# leuning computation module at 132 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00181314 3.10395e-06 3.7765e-05 7.31328e-06 0.0018401 0.0168026 0 4.67363 6.76221e-05
# each val abs 1.65655 3.04604e-11 6.48989e-06 2.11621e-09 1.68116 0.000317546 0 0.0128038 6.63589e-10
# leuning computation module at 133 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00178142 3.05706e-06 3.71929e-05 7.20275e-06 0.00180792 0.0168164 0 4.6761 6.6592e-05
# each val abs 1.63052 3.00002e-11 6.39132e-06 2.08422e-09 1.65475 0.000312575 0 0.0126023 6.53479e-10
# leuning computation module at 134 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00175031 3.01085e-06 3.6629e-05 7.09382e-06 0.00177635 0.0168304 0 4.67861 6.55772e-05
# each val abs 1.6049 2.95466e-11 6.2942e-06 2.05268e-09 1.62875 0.000307681 0 0.0124041 6.43519e-10
# leuning computation module at 135 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0017198 2.96531e-06 3.60733e-05 6.98647e-06 0.00174539 0.0168446 0 4.68117 6.45773e-05
# each val abs 1.57968 2.90996e-11 6.19849e-06 2.0216e-09 1.60316 0.000302862 0 0.0122089 6.33705e-10
# leuning computation module at 136 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00168987 2.92042e-06 3.55258e-05 6.88067e-06 0.00171502 0.0168591 0 4.68378 6.35921e-05
# each val abs 1.55486 2.8659e-11 6.10418e-06 1.99097e-09 1.57797 0.000298117 0 0.0120168 6.24036e-10
# leuning computation module at 137 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0016605 2.87619e-06 3.49862e-05 6.7764e-06 0.00168522 0.0168739 0 4.68643 6.26216e-05
# each val abs 1.53042 2.82248e-11 6.01126e-06 1.96079e-09 1.55317 0.000293446 0 0.0118278 6.1451e-10
# leuning computation module at 138 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0016317 2.83259e-06 3.44545e-05 6.67365e-06 0.00165599 0.0168889 0 4.68913 6.16653e-05
# each val abs 1.50637 2.7797e-11 5.91969e-06 1.93105e-09 1.52876 0.000288847 0 0.0116417 6.05126e-10
# leuning computation module at 139 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00160344 2.78964e-06 3.39305e-05 6.5724e-06 0.00162732 0.0169043 0 4.69188 6.07233e-05
# each val abs 1.4827 2.73753e-11 5.82948e-06 1.90174e-09 1.50474 0.000284319 0 0.0114586 5.9588e-10
# leuning computation module at 140 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00157571 2.7473e-06 3.34143e-05 6.47262e-06 0.00159918 0.0169198 0 4.69468 5.97952e-05
# each val abs 1.4594 2.69598e-11 5.74059e-06 1.87285e-09 1.48109 0.000279861 0 0.0112783 5.86771e-10
# leuning computation module at 141 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00154851 2.70559e-06 3.29056e-05 6.3743e-06 0.00157157 0.0169357 0 4.69753 5.88809e-05
# each val abs 1.43646 2.65504e-11 5.65301e-06 1.84439e-09 1.45781 0.000275473 0 0.0111009 5.77798e-10
# leuning computation module at 142 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00152181 2.66448e-06 3.24043e-05 6.27742e-06 0.00154448 0.0169519 0 4.70043 5.79802e-05
# each val abs 1.41388 2.6147e-11 5.56672e-06 1.81635e-09 1.4349 0.000271152 0 0.0109263 5.68958e-10
# leuning computation module at 143 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00149561 2.62398e-06 3.19105e-05 6.18195e-06 0.0015179 0.0169684 0 4.70338 5.70929e-05
# each val abs 1.39166 2.57494e-11 5.4817e-06 1.78871e-09 1.41235 0.000266898 0 0.0107544 5.6025e-10
# leuning computation module at 144 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00146991 2.58406e-06 3.14239e-05 6.08788e-06 0.00149181 0.0169851 0 4.70639 5.62188e-05
# each val abs 1.36978 2.53577e-11 5.39795e-06 1.76148e-09 1.39015 0.000262711 0 0.0105852 5.51671e-10
# leuning computation module at 145 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00144468 2.54474e-06 3.09445e-05 5.99519e-06 0.00146621 0.0170022 0 4.70944 5.53577e-05
# each val abs 1.34825 2.49717e-11 5.31543e-06 1.73466e-09 1.3683 0.000258589 0 0.0104187 5.4322e-10
# leuning computation module at 146 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00141992 2.50599e-06 3.04721e-05 5.90387e-06 0.00144108 0.0170196 0 4.71255 5.45094e-05
# each val abs 1.32706 2.45914e-11 5.23413e-06 1.70822e-09 1.34679 0.000254531 0 0.0102548 5.34895e-10
# leuning computation module at 147 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00139561 2.46781e-06 3.00068e-05 5.81389e-06 0.00141642 0.0170373 0 4.71572 5.36738e-05
# each val abs 1.3062 2.42166e-11 5.15405e-06 1.68218e-09 1.32562 0.000250536 0 0.0100935 5.26694e-10
# leuning computation module at 148 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00137176 2.43019e-06 2.95483e-05 5.72523e-06 0.00139221 0.0170553 0 4.71895 5.28507e-05
# each val abs 1.28566 2.38474e-11 5.07515e-06 1.65652e-09 1.30478 0.000246603 0 0.00993477 5.18616e-10
# leuning computation module at 149 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00134835 2.39312e-06 2.90966e-05 5.63788e-06 0.00136845 0.0170736 0 4.72223 5.20399e-05
# each val abs 1.26545 2.34837e-11 4.99742e-06 1.63123e-09 1.28427 0.000242732 0 0.00977851 5.10658e-10
# leuning computation module at 150 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00132536 2.35661e-06 2.86516e-05 5.55182e-06 0.00134513 0.0170923 0 4.72557 5.12412e-05
# each val abs 1.24556 2.31253e-11 4.92085e-06 1.60632e-09 1.26408 0.000238921 0 0.00962471 5.0282e-10
# leuning computation module at 151 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0013028 2.32063e-06 2.82132e-05 5.46703e-06 0.00132223 0.0171114 0 4.72896 5.04544e-05
# each val abs 1.22597 2.27722e-11 4.84542e-06 1.58178e-09 1.2442 0.000235169 0 0.00947332 4.95099e-10
# leuning computation module at 152 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00128065 2.28518e-06 2.77813e-05 5.3835e-06 0.00129975 0.0171308 0 4.73242 4.96795e-05
# each val abs 1.2067 2.24243e-11 4.77111e-06 1.55761e-09 1.22464 0.000231476 0 0.00932432 4.87493e-10
# leuning computation module at 153 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0012589 2.25026e-06 2.73559e-05 5.3012e-06 0.00127768 0.0171505 0 4.73594 4.89161e-05
# each val abs 1.18773 2.20816e-11 4.69792e-06 1.53379e-09 1.20539 0.000227841 0 0.00917767 4.80002e-10
# leuning computation module at 154 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00123755 2.21586e-06 2.69367e-05 5.22013e-06 0.00125602 0.0171706 0 4.73953 4.81642e-05
# each val abs 1.16906 2.17439e-11 4.62582e-06 1.51032e-09 1.18644 0.000224262 0 0.00903332 4.72623e-10
# leuning computation module at 155 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00121659 2.18196e-06 2.65239e-05 5.14025e-06 0.00123474 0.0171911 0 4.74317 4.74237e-05
# each val abs 1.15067 2.14113e-11 4.55479e-06 1.4872e-09 1.16779 0.00022074 0 0.00889124 4.65355e-10
# leuning computation module at 156 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00119601 2.14857e-06 2.61171e-05 5.06157e-06 0.00121385 0.0172119 0 4.74689 4.66942e-05
# each val abs 1.13258 2.10836e-11 4.48483e-06 1.46443e-09 1.14943 0.000217272 0 0.0087514 4.58196e-10
# leuning computation module at 157 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.0011758 2.11568e-06 2.57165e-05 4.98405e-06 0.00119334 0.0172332 0 4.75066 4.59757e-05
# each val abs 1.11478 2.07607e-11 4.41591e-06 1.442e-09 1.13135 0.000213859 0 0.00861376 4.51145e-10
# leuning computation module at 158 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00115595 2.08327e-06 2.53218e-05 4.90769e-06 0.0011732 0.0172548 0 4.75451 4.5268e-05
# each val abs 1.09725 2.04427e-11 4.34803e-06 1.4199e-09 1.11357 0.000210499 0 0.00847828 4.442e-10
# leuning computation module at 159 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00113646 2.05135e-06 2.4933e-05 4.83247e-06 0.00115342 0.0172769 0 4.75842 4.4571e-05
# each val abs 1.08 2.01294e-11 4.28117e-06 1.39813e-09 1.09606 0.000207192 0 0.00834494 4.37359e-10
# leuning computation module at 160 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00111732 2.01991e-06 2.45501e-05 4.75837e-06 0.001134 0.0172993 0 4.76241 4.38845e-05
# each val abs 1.06302 1.98208e-11 4.21531e-06 1.37668e-09 1.07882 0.000203937 0 0.0082137 4.30622e-10
# leuning computation module at 161 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00109853 1.98893e-06 2.41729e-05 4.68537e-06 0.00111493 0.0173222 0 4.76646 4.32083e-05
# each val abs 1.0463 1.95168e-11 4.15045e-06 1.35556e-09 1.06186 0.000200732 0 0.00808452 4.23986e-10
# leuning computation module at 162 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00108007 1.95841e-06 2.38013e-05 4.61347e-06 0.00109619 0.0173455 0 4.77059 4.25423e-05
# each val abs 1.02985 1.92173e-11 4.08655e-06 1.33475e-09 1.04516 0.000197578 0 0.00795737 4.17451e-10
# leuning computation module at 163 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00106194 1.92836e-06 2.34353e-05 4.54264e-06 0.00107779 0.0173692 0 4.77479 4.18864e-05
# each val abs 1.01366 1.89224e-11 4.02362e-06 1.31425e-09 1.02873 0.000194473 0 0.00783222 4.11014e-10
# leuning computation module at 164 trials. Sum of max relative error calculated at the last two trials: 0
# each val 0.00104413 1.89875e-06 2.30749e-05 4.47287e-06 0.00105972 0.0173934 0 4.77907 4.12404e-05
# each val abs 0.997718 1.86318e-11 3.96164e-06 1.29406e-09 1.01256 0.000191417 0 0.00770904 4.04675e-10
# leuning computation module at 165 trials. Sum of max relative error calculated at the last two trials: 1
# each val 0.00102664 1.86958e-06 2.27198e-05 4.40414e-06 0.00104197 0.0174181 0 4.78342 4.06042e-05
# each val abs 0.982029 1.83456e-11 3.90059e-06 1.27417e-09 0.996634 0.000188409 0 0.0075878 3.98431e-10
# leuning computation module stopped after 166 trials. Sum of max relative error calculated at the last two trials: 1
# each val 0.00102664 1.86958e-06 2.27198e-05 4.40414e-06 0.00104197 0.0174181 0 4.78342 4.06042e-05
# each val abs 0.982029 1.83456e-11 3.90059e-06 1.27417e-09 0.996634 0.000188409 0 0.0075878 3.98431e-10

# %% [markdown]
# Present outputs:

# %%
plantWatPot = r.psiXyl
fluxes = r.radial_fluxes(simtime, plantWatPot, p_s,[], True)  # cm3/day
surfs = np.multiply(np.array(r.rs.segLength()), 2*np.array(r.rs.radii)*np.pi)  # root segment side surface [cm2]
fluxes = np.divide(fluxes, surfs)  # we convert to [cm3/(cm2 day)]

""" plot results """

fig, ax = plt.subplots()
name = ["root", "stem", "leaf"]
color = ['tab:blue', 'tab:orange', 'tab:green']
for ndType in [2, 3, 4]:
    #nodes = self.get_nodes()
    y = r.get_nodes_organ_type(ndType)#coordinates
    x = np.array(plantWatPot)[r.get_nodes_index(ndType)]
    ax.scatter(x, y[:,2], c=color[ndType-2],  label=name[ndType-2],
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)
plt.xlabel("Xylem pressure (cm)")
plt.ylabel("Depth (cm)")
plt.title("Xylem matric potential (cm)")
plt.show()


fig, ax = plt.subplots()
name = ["root", "stem", "leaf"]
color = ['tab:blue', 'tab:orange', 'tab:green']
for ndType in [2, 3, 4]:
    segIdx = r.get_segments_index(ndType)
    nodesy = segIdx + np.ones(segIdx.shape, dtype = np.int64)
    nodes = r.get_nodes()
    y = np.array(nodes)[nodesy]#coordinates
    x = fluxes[segIdx]
    ax.scatter(x, y[:,2], c=color[ndType-2],  label=name[ndType-2],
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)
plt.xlabel("Fluxes (cm/day)")
plt.ylabel("Depth (cm)")
plt.title("water fluxes")
plt.show()


print("Transpiration", sum(fluxes[r.get_segments_index(4)]), "cm3/day")
print("Net assimilation", np.sum(r.An)*1e3, "mmol CO2 m-2 s-1")
# Out:
# Transpiration 0.13929617620306106 cm3/day
# Net assimilation 0.2649380603135443 mmol CO2 m-2 s-1

# %% [markdown]
# ## Take away messages
#
# * Basic idea how to use the class *Photosynthesis*
# * How to set the root axial and radial conductivities in the class *MappedPlantSystem*
# * How to use *MappedPlantSystem* to couple the segments to a soil grid
# * Look at the outputs of the photosynthesis model
