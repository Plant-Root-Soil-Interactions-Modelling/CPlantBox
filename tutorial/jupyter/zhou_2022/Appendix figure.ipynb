# %%
import plotly
import plotly.express as px
import pandas as pd

# %%
# time = 30
# df = pd.read_csv("case_1.1.1_0.1cm.xml_11_0.8_0.8_0.8_10.csv")
# df = pd.read_csv("case_1.1.2_0.2cm.xml_11_0.8_0.8_0.8_10.csv")
df = pd.read_csv("Study1/case_01_0.05cm_lateral_radius.xml_16_2_0_fixed_res_10_trsv_20220621_8resis_high_rst_15-6-23-14-39.csv")


# case_01_0.05cm_lateral_radius.xml_16_2_0_0_res_25_trsv_20220621_8resis_high_rst_15-6-24-12-51.csv
# df = pd.read_csv("case_1.1.3_0.3cm.xml_11_0.8_0.8_0.8_10.csv")

df = df[df['time'] == 4]

df.loc[:,'growth_rate']= df.loc[:,'growth_rate'].fillna(0)

fig = px.scatter_3d(df, x="coor_x", y="coor_y", z = "coor_z" ,animation_frame="time", animation_group="order",
           size="radius", color="P_ST", hover_name="id", color_continuous_scale=px.colors.sequential.Plasma_r,
           log_x=False)
plotly.offline.plot(fig, filename='id_offline.html')
fig.update_traces(marker=dict(
                              line=dict(width=0,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
scence = dict(xaxis_title='X AXIS ',
                        yaxis_title='Y AXIS ',
                        zaxis_title='Z AXIS ',
                    xaxis = dict(
                         backgroundcolor="rgb(250, 250, 250)",
                         gridcolor="lightgrey",
                         showbackground=True,
                         zerolinecolor="black",),
                    yaxis = dict(
                        backgroundcolor="rgb(250, 250,250)",
                        gridcolor="lightgrey",
                        showbackground=True,
                        zerolinecolor="black"),
                    zaxis = dict(
                        backgroundcolor="rgb(250, 250,250)",
                        gridcolor="lightgrey",
                        showbackground=True,
                        zerolinecolor="black",),)

scence = dict(
    xaxis_title='',
                        yaxis_title='',
                        zaxis_title='',
                    xaxis = dict(
                         backgroundcolor="rgb(250, 250, 250)",
                         gridcolor="lightgrey",
                         showbackground=True,
                         zerolinecolor="black",
                    showticklabels=False),
                    yaxis = dict(
                        backgroundcolor="rgb(250, 250,250)",
                        gridcolor="lightgrey",
                        showbackground=True,
                        zerolinecolor="black",
                    showticklabels=False),
                    zaxis = dict(
                        backgroundcolor="rgb(250, 250,250)",
                        gridcolor="lightgrey",
                        showbackground=True,
                        zerolinecolor="black",
                    showticklabels=False),)
fig.update_layout(coloraxis_colorbar=dict(
    title=dict(
        text='segsg',
        font=dict(
            family="Arial",
            size=28,
            color='#000000'
        )),
    thicknessmode="pixels", thickness=16,
    lenmode="pixels", len=350,
    tickfont = {"size": 18}
    

))
camera = dict(
    up=dict(x=0, y=0, z=1),
    center=dict(x=0, y=0, z=0),
    eye=dict(x=2.5, y=2.5, z=2.5)
)
scence = dict(
    xaxis_title='',
                        yaxis_title='',
                        zaxis_title='',
                    xaxis = dict(
                         backgroundcolor="rgb(250, 250, 250)",
                         gridcolor="lightgrey",
                         showbackground=True,
                         zerolinecolor="black",
                    showticklabels=False),
                    yaxis = dict(
                        backgroundcolor="rgb(250, 250,250)",
                        gridcolor="lightgrey",
                        showbackground=True,
                        zerolinecolor="black",
                    showticklabels=False),
                    zaxis = dict(
                        backgroundcolor="rgb(250, 250,250)",
                        gridcolor="lightgrey",
                        showbackground=True,
                        zerolinecolor="black",
                    showticklabels=False),)
fig.update_layout(autosize=False,  scene = scence, scene_camera= camera, width =400,
                        height = 800,
                        margin=dict(r=0, b=0, l=0, t=60), title=dict(
        text='<b>C.3</b> rgwae',
        x=0.5,
        y=0.95,
        font=dict(
            family="Arial",
            size=36,
            color='#000000'
        )))
fig.update_layout(scene_aspectmode='data')
fig.show()
# fig.

# %%
import plotly.io as pio
pio.orca.config.use_xvfb = True

# %%
.__version__

# %%
def node_fig(name, time, attri, title, unit):
    df = pd.read_csv(name)

    # df = pd.read_csv("case_1.1.3_0.3cm.xml_11_0.8_0.8_0.8_10.csv")

    df = df[df['time'] == time]

    df.loc[:,'growth_rate']= df.loc[:,'growth_rate'].fillna(0)

    fig = px.scatter_3d(df, x="coor_x", y="coor_y", z = "coor_z" ,animation_frame="time", animation_group="order",
               size="radius", color=attri, hover_name="id", color_continuous_scale=px.colors.sequential.Bluered,
               log_x=False)
    
    fig.update_traces(marker=dict(
                                  line=dict(width=0,
                                            color='DarkSlateGrey')),
                      selector=dict(mode='markers'))
    scence = dict(xaxis_title='X AXIS ',
                            yaxis_title='Y AXIS ',
                            zaxis_title='Z AXIS ',
                        xaxis = dict(
                             backgroundcolor="rgb(250, 250, 250)",
                             gridcolor="lightgrey",
                             showbackground=True,
                             zerolinecolor="black",),
                        yaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black"),
                        zaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black",),)


    fig.update_layout(coloraxis_colorbar=dict(
        title=dict(
            text='{}'.format(unit),
            font=dict(
                family="Arial",
                size=28,
                color='#000000'
            )),
        thicknessmode="pixels", thickness=16,
        lenmode="pixels", len=350,
        tickfont = {"size": 18}


    ))
    camera = dict(
        up=dict(x=0, y=0, z=1),
        center=dict(x=0, y=0, z=0),
        eye=dict(x=0, y=-2, z=0)
    )
    scence = dict(
        xaxis_title='',
                            yaxis_title='',
                            zaxis_title='',
                        xaxis = dict(
                             backgroundcolor="rgb(250, 250, 250)",
                             gridcolor="lightgrey",
                             showbackground=True,
                             zerolinecolor="black",
                             range=[-0.11,0.11],
                        showticklabels=False),
                        yaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black",
                            range=[-0.11,0.11],
                        showticklabels=False),
                        zaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black",
                            range=[-0.24,0.13],
                        showticklabels=False),)
    fig.update_layout(autosize=False,  scene = scence, scene_camera= camera, width =600,
                            height = 800,
                            margin=dict(r=0, b=0, l=0, t=60), title=dict(
            text='<b>{}</b> {}'.format(i, title),
            x=0.5,
            y=0.95,
            font=dict(
                family="Arial",
                size=36,
                color='#000000'
            )))
    fig.update_layout(scene_aspectmode='manual', scene_aspectratio=dict(x=1, y=1, z=2))
    fig.write_html("{}.html".format(title))
    fig.show()
#     fig.to_image(format="svg", engine="kaleido")
#     fig.write_image("/mnt/e/git/cpb-binder/tutorial/jupyter/images/aa{}.svg".format(attri))
    # fig.

# %%
for i in range(1,16):
    node_fig("Study1/case_01_0.05cm_lateral_radius.xml_16_0_0_0_res_10_water_5rst_1_15-6-29-12-15.csv",
             i, 
             "JW_Trsv", 
             "Apoplastic water transfer {}".format(i), 
             "ml")

# %%
for i in range(1,16):
    node_fig("Study1/case_01_0.05cm_lateral_radius.xml_16_0_0_0_res_10_water_5rst_1_15-6-29-12-15.csv",
             i, 
             "JW_Trsv", 
             "JW_Trsv on day {}".format(i), 
             "mmol")

# %%
for i in range(1,16):
    node_fig("Study1/case_01_0.05cm_lateral_radius.xml_16_0_0_0_res_10_water_5rst_1_15-6-29-12-15.csv",
             i, 
             "r_st", 
             "sieve-tube carbon content on day {}".format(i), 
             "MPa")

# %%
d1

# %%
path = "/mnt/e/git/cpb-binder/tutorial/jupyter/images/appendix-image/"
files = os.listdir(path)

# %%
files

# %%
figures = filter(lambda figure: figure.find('2022-06-29T173')!=-1, files )

# %%
os.system('''
montage  
"images/appendix-image/{}" "images/appendix-image/{}"  "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}"  "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" -tile 5x3 -geometry 800x600+2+30   images/figure.jpg
'''.format(*tuple(a))
)

# %%
os.system('''
montage  
"images/appendix-image/{}"
"images/appendix-image/{}" 
"images/appendix-image/{}" 
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}"
"images/appendix-image/{}" -tile 5x3 -geometry 800x600+2+30   images/figure.jpg
'''.format(*tuple(a))
)

# %%
b= list(figures)

# %%
os.system(

# %%
b

# %%
from datetime import datetime
import os
b= []
for i in range(15):
    b.append("newplot ({}).png".format(i+7))
os.system('montage   "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}"  "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" "images/appendix-image/{}" -tile 3x5 -geometry 800x600+2+2   images/figure1.jpg'.format(*tuple(b)))

# %%
b

# %%
# %%javascript
# //var previousCell =Jupyter.notebook.select_prev().get_selected_cell();
# // element.text(Jupyter.notebook.select_prev().get_selected_celvl())
# var a= document.querySelectorAll('[data-title="Download plot as a png"]');
# // a[0].click()
# element.text(a.length)
# for (let i = 1; i <= a.length; i++) {
#     setTimeout(function() {a[i].click()}, i*1000 );
#
# }

# %%
# %%javascript
# var a= document.querySelectorAll('[data-title="Download plot as a png"]');

# %%
from datetime import datetime
import os

# path = "/mnt/e/git/cpb-binder/tutorial/jupyter/images/appendix-image/"
# files = os.listdir(path)

# today = datetime.now()
# d1 = today.strftime("%Y-%m-%dT%H")

# time_date = d1


# a = list(filter(lambda figure: figure.find(time_date)!=-1, files ))
for index, value in enumerate(a):
#     print(value)
    os.system('mv "/mnt/e/git/cpb-binder/tutorial/jupyter/images/appendix-image/{}" /mnt/e/git/cpb-binder/tutorial/jupyter/images/appendix-image/figure{number:02d}.png'.format(value, index))

# %%
os.system("mv /mnt/e/git/cpb-binder/tutorial/jupyter/images/appendix-image/newplot - 2022-06-29T173432.836.png ")

# %%
import plotly.express as px
import pandas as pd
# df = pd.read_csv("small_2020.xml_31_0.1_0.1_0.1.csv")
# df= pd.read_csv("small_2020_abs.xml_31_0.1_0.1_0.1_30.csv")
# df = pd.read_csv("case_1.1.1_0.1cm.xml_11_0.8_0.8_11_10.csv")
def connect_fig(name, time, attri, title, unit):
    df = pd.read_csv(name)
    # df = pd.read_csv("case_1_lateral_radius.xml_30_0.8_0.8_11_29.csv")


    time =time


    df_1 = df[df["time"] == time]
    c1 = df_1["connection_1"].tolist()
    c2 = df_1["connection_2"][:-1].astype(int).tolist()
    radius_n = df_1['radius'].tolist()

    cx = df_1["coor_x"].tolist()
    cy = df_1["coor_y"].tolist()
    cz= df_1["coor_z"].tolist()
    rst= df_1["r_st"].tolist()
    rxyl= df_1["r_xyl"].tolist()
    cc= df_1["connect_no"].tolist()
    jwxyl= df_1["JW_Xyl"].tolist()
    jwst= df_1["JW_ST"].tolist()
    jsst= df_1["JS_ST"].tolist()
    radius =list(map(lambda x:radius_n[x-1],  c2 ))
    # cxyl1 = map(lambda x: x/10, cxyl)

    con_x = []
    con_y = []
    con_z = []
    ccc = []
    for i in range(0, len(c1)-1):
        con_x.append( (cx[int(c1[i]-1)] + cx[int(c2[i]-1)] )/2    )
        con_y.append( (cy[int(c1[i]-1)] + cy[int(c2[i]-1)] )/2    )
        con_z.append( (cz[int(c1[i]-1)] + cz[int(c2[i]-1)] )/2    )
        ccc.append(cc[int(c1[i]-1)])
    df2 = pd.DataFrame(list(zip(con_x, con_y,con_z, rst, rxyl,ccc, radius,jwxyl,jwst)), 
                   columns =['con_x', 'con_y','con_z', 'rst', 'xylem_axial_resistance','ccc','radius', 'axial_water','phloem carbon flow']) 

    fig = px.scatter_3d(df2, x="con_x", y="con_y", z = "con_z" ,
               size=radius, color=attri, color_continuous_scale=px.colors.sequential.Plasma_r,
               log_x=False)

    fig.update_traces(marker=dict(
                                  line=dict(width=0,
                                            color='DarkSlateGrey')),
                      selector=dict(mode='markers'))
    
    
    
    scence = dict(xaxis_title='X AXIS ',
                            yaxis_title='Y AXIS ',
                            zaxis_title='Z AXIS ',
                        xaxis = dict(
                             backgroundcolor="rgb(250, 250, 250)",
                             gridcolor="lightgrey",
                             showbackground=True,
                             zerolinecolor="black",),
                        yaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black"),
                        zaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black",),)


    fig.update_layout(coloraxis_colorbar=dict(
        title=dict(
            text='{}'.format(unit),
            font=dict(
                family="Arial",
                size=28,
                color='#000000'
            )),
        thicknessmode="pixels", thickness=16,
        lenmode="pixels", len=350,
        tickfont = {"size": 18}


    ))
    camera = dict(
        up=dict(x=0, y=0, z=1),
        center=dict(x=0, y=0, z=0),
        eye=dict(x=0, y=-2, z=0)
    )
    scence = dict(
        xaxis_title='',
                            yaxis_title='',
                            zaxis_title='',
                        xaxis = dict(
                             backgroundcolor="rgb(250, 250, 250)",
                             gridcolor="lightgrey",
                             showbackground=True,
                             zerolinecolor="black",
                             range=[-0.11,0.11],
                        showticklabels=False),
                        yaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black",
                            range=[-0.11,0.11],
                        showticklabels=False),
                        zaxis = dict(
                            backgroundcolor="rgb(250, 250,250)",
                            gridcolor="lightgrey",
                            showbackground=True,
                            zerolinecolor="black",
                            range=[-0.24,0.13],
                        showticklabels=False),)
    fig.update_layout(autosize=False,  scene = scence, scene_camera= camera, width =600,
                            height = 800,
                            margin=dict(r=0, b=0, l=0, t=60), title=dict(
            text='<b>{}</b> {}'.format(time, title),
            x=0.5,
            y=0.95,
            font=dict(
                family="Arial",
                size=36,
                color='#000000'
            )))
    fig.update_layout(scene_aspectmode='manual', scene_aspectratio=dict(x=1, y=1, z=2))
    fig.show()

# %%
for i in range(1,16):

    connect_fig("Study1/case_01_0.05cm_lateral_radius.xml_16_0_0_0_res_10_water_5rst_1_15-6-29-12-15.csv", 
                i, 
                "phloem carbon flow", 
                "phloem carbon flow on day {}".format(i), 
                "mmol/h")

# %%
connect_fig("Study1/case_01_0.05cm_lateral_radius.xml_16_0_0_0_res_10_water_5rst_1_15-6-29-12-15.csv", 15, "phloem carbon flow", "phloem carbon flow", "unit")
